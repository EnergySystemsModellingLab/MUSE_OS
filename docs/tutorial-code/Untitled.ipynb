# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("1-add-new-technology/1-introduction/Results/MCACapacity.csv")
g = sns.FacetGrid(data=data, col="sector")
g.map(sns.lineplot, "year", "capacity", "technology")
g.add_legend()

# %%
data = pd.read_csv("1-add-new-technology/2-scenario/Results/MCACapacity.csv")
g = sns.FacetGrid(data=data, col="sector")
g.map(sns.lineplot, "year", "capacity", "technology")
g.add_legend()

# %%
data = pd.read_csv("2-add-agent/1-multiple-objective/Results/MCACapacity.csv")
g = sns.FacetGrid(data=data, row="sector", col="agent")
g.map(sns.lineplot, "year", "capacity", "technology")
g.add_legend()

# %%
data = pd.read_csv("2-add-agent/1-multiple-objective/Results/MCACapacity.csv")
g = sns.FacetGrid(data=data, row="sector", col="agent")
g.map(sns.lineplot, "year", "capacity", "technology")
g.add_legend()

# %%
data = pd.read_csv("2-add-agent/2-single-objective/Results/MCACapacity.csv")
g = sns.FacetGrid(data=data, row="sector", col="agent")
g.map(sns.lineplot, "year", "capacity", "technology")
g.add_legend()

# %%
data = pd.read_csv("3-add-region/Results/MCACapacity.csv")
g = sns.FacetGrid(data=data, row="sector", col="agent")
g.map(sns.lineplot, "year", "capacity", "technology")
g.add_legend()

# %%
data = pd.read_csv("4-modify-timing-data/1-modify-timeslices/Results/MCACapacity.csv")
g = sns.FacetGrid(data=data, row="sector", col="agent")
g.map(sns.lineplot, "year", "capacity", "technology")
g.add_legend()

# %%
data = pd.read_csv("4-modify-timing-data/2-modify-time-framework/Results/MCACapacity.csv")
g = sns.FacetGrid(data=data, row="sector", col="agent")
g.map(sns.lineplot, "year", "capacity", "technology")
g.add_legend()

# %%
data = pd.read_csv("5-add-service-demand/Results/MCACapacity.csv")
g = sns.FacetGrid(data=data, row="sector", col="agent")
g.map(sns.lineplot, "year", "capacity", "technology")
g.add_legend()
